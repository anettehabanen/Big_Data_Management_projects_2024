# %%
# This is the project code.

# %%
import pyspark
from delta import *

builder = pyspark.sql.SparkSession.builder.appName("DF2_Practice") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") 

spark = configure_spark_with_delta_pip(builder).getOrCreate()

spark.conf.set("spark.sql.repl.eagerEval.enabled",True) # OK for exploration, not great for performance
spark.conf.set("spark.sql.repl.eagerEval.truncate", 500)

# %%
import pandas as pd
import json
import numpy as np
import shapely
from shapely import Point
from shapely.geometry import mapping, shape
import pyspark.sql.functions as F
from pyspark.sql import Window
from shapely import Polygon
from pyspark.sql.functions import col, count, when
from pyspark.sql.types import DoubleType
from shapely.strtree import STRtree

# %% [markdown]
# ## Reading in data

# %%
# Reading in taxi dataset
taxiDataDf = (spark.read
             .option("sep", ",") # separator
             .option("header", True) # file has header row
             .option("inferSchema", True) # spark tries to infer data types
             .csv("sample.csv") #path
            )

# %%
display(taxiDataDf)
# Out:
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+
# |                       medallion|                    hack_license|vendor_id|rate_code|store_and_fwd_flag|    pickup_datetime|   dropoff_datetime|passenger_count|trip_time_in_secs|trip_distance|pickup_longitude|pickup_latitude|dropoff_longitude|dropoff_latitude|
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+
# |89D227B655E5C82AECF13C3F540D4CF4|BA96DE419E711691B9445D6A6307C170|      CMT|        1|                 N|2013-01-01 15:11:48|2013-01-01 15:18:10|              4|              382|          1.0|      -73.978165|      40.757977|       -73.989838|       40.751171|
# |0BD7C8F5BA12B88E0B67BED28BEA73D8|9FD8F69F0804BDB5549F40E9DA1BE472|      CMT|        1|                 N|2013-01-06 00:18:35|2013-01-06 00:22:54|              1|              259|          1.5|      -74.006683|      40.731781|       -73.994499|        40.75066|
# |0BD7C8F5BA12B88E0B67BED28BEA73D8|9FD8F69F0804BDB5549F40E9DA1BE472|      CMT|        1|                 N|2013-01-05 18:49:41|2013-01-05 18:54:23|              1|              282|          1.1|      -74.004707|       40.73777|       -74.009834|       40.726002|
# |DFD2202EE08F7A8DC9A57B02ACB81FE2|51EE87E3205C985EF8431D850C786310|      CMT|        1|                 N|2013-01-07 23:54:15|2013-01-07 23:58:20|              2|              244|          0.7|      -73.974602|      40.759945|       -73.984734|       40.759388|
# |DFD2202EE08F7A8DC9A57B02ACB81FE2|51EE87E3205C985EF8431D850C786310|      CMT|        1|                 N|2013-01-07 23:25:03|2013-01-07 23:34:24|              1|              560|          2.1|       -73.97625|      40.748528|       -74.002586|       40.747868|
# |20D9ECB2CA0767CF7A01564DF2844A3E|598CCE5B9C1918568DEE71F43CF26CD2|      CMT|        1|                 N|2013-01-07 15:27:48|2013-01-07 15:38:37|              1|              648|          1.7|      -73.966743|      40.764252|       -73.983322|       40.743763|
# |496644932DF3932605C22C7926FF0FE0|513189AD756FF14FE670D10B92FAF04C|      CMT|        1|                 N|2013-01-08 11:01:15|2013-01-08 11:08:14|              1|              418|          0.8|      -73.995804|      40.743977|       -74.007416|       40.744343|
# |0B57B9633A2FECD3D3B1944AFC7471CF|CCD4367B417ED6634D986F573A552A62|      CMT|        1|                 N|2013-01-07 12:39:18|2013-01-07 13:10:56|              3|             1898|         10.7|      -73.989937|      40.756775|        -73.86525|        40.77063|
# |2C0E91FF20A856C891483ED63589F982|1DA2F6543A62B8ED934771661A9D2FA0|      CMT|        1|                 N|2013-01-07 18:15:47|2013-01-07 18:20:47|              1|              299|          0.8|      -73.980072|      40.743137|       -73.982712|       40.735336|
# |2D4B95E2FA7B2E85118EC5CA4570FA58|CD2F522EEE1FF5F5A8D8B679E23576B3|      CMT|        1|                 N|2013-01-07 15:33:28|2013-01-07 15:49:26|              2|              957|          2.5|      -73.977936|      40.786983|       -73.952919|        40.80637|
# |E12F6AF991172EAC3553144A0AF75A19|06918214E951FA0003D1CC54955C2AB0|      CMT|        1|                 N|2013-01-08 13:11:52|2013-01-08 13:19:50|              1|              477|          1.3|      -73.982452|      40.773167|       -73.964134|       40.773815|
# |E12F6AF991172EAC3553144A0AF75A19|06918214E951FA0003D1CC54955C2AB0|      CMT|        1|                 N|2013-01-08 09:50:05|2013-01-08 10:02:54|              1|              768|          0.7|       -73.99556|      40.749294|       -73.988686|       40.759052|
# |78FFD9CD0CDA541F335EF8B38FB494D6|E949C583ECF62C8F03FDCE1484954A08|      CMT|        1|                 N|2013-01-10 12:07:08|2013-01-10 12:17:29|              1|              620|          2.3|      -73.971497|      40.791321|       -73.964478|       40.775921|
# |237F49C3ECC11F5024B254268F054384|93C363DDF8ED9385D65FAD07CE3F5F07|      CMT|        1|                 N|2013-01-07 07:35:47|2013-01-07 07:46:00|              1|              612|          2.3|       -73.98851|      40.774307|       -73.981094|       40.755325|
# |3349F919AA8AE5DC9C50A3773EA45BD8|7CE849FEF67514F080AF80D990F7EF7F|      CMT|        1|                 N|2013-01-10 15:42:29|2013-01-10 16:04:02|              1|             1293|          3.2|      -73.994911|      40.723221|       -73.971558|       40.761612|
# |3349F919AA8AE5DC9C50A3773EA45BD8|7CE849FEF67514F080AF80D990F7EF7F|      CMT|        1|                 N|2013-01-10 14:27:28|2013-01-10 14:45:21|              1|             1073|          4.4|      -74.010391|      40.708702|       -73.987846|       40.756104|
# |4C005EEBAA7BF26B84B21586332488A2|351BE7D984BE17DB2FA80A748E816472|      CMT|        1|                 N|2013-01-07 22:09:59|2013-01-07 22:19:50|              1|              591|          1.7|      -73.973732|      40.756287|       -73.998413|       40.756832|
# |7D99C30FCE69B1A9DD27E2AEAC9BFA0C|460C3F57DD9CB2265DB75B14CD70224D|      CMT|        1|                 N|2013-01-07 17:18:16|2013-01-07 17:20:55|              1|              158|          0.7|      -73.968925|      40.767704|        -73.96199|       40.776566|
# |E6FBF80668FE0611AEA44FD9574A7E32|36773E80775F26CD1158EB5450A61C79|      CMT|        1|                 N|2013-01-07 06:08:51|2013-01-07 06:13:14|              1|              262|          1.7|       -73.96212|      40.769737|       -73.979561|        40.75539|
# |0C5296F3C8B16E702F8F2E06F5106552|D2363240A9295EF570FC6069BC4F4C92|      CMT|        1|                 N|2013-01-07 22:25:46|2013-01-07 22:36:56|              1|              669|          2.3|      -73.989708|      40.756714|       -73.977615|       40.787575|
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+
# only showing top 20 rows

# %%
# Reading in borough dataset
with open('nyc-boroughs.geojson') as file:
    boroughs = json.load(file)

features = boroughs['features']
properties = [feature['properties'] for feature in features]
geometry = [feature['geometry'] for feature in features]

properties_df = spark.createDataFrame(properties).withColumn("rid",F.monotonically_increasing_id())
geometry_df = spark.createDataFrame(geometry).withColumn("rid",F.monotonically_increasing_id())
#borough_base_df = pd.concat([pd.DataFrame(properties), pd.DataFrame(geometry)], axis=1)
borough_base_df = properties_df.join(geometry_df,("rid")).drop("rid")

# %%
display(borough_base_df)
# Out:
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |                                                      @id|      borough|boroughCode|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         coordinates|   type|
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |http://nyc.pediacities.com/Resource/Borough/Staten_Island|Staten Island|          5|                                                                                                                                  [[[-74.05050806403247, 40.566422034160816], [-74.04998352562575, 40.56639592492827], [-74.04931640362088, 40.56588774778044], [-74.04923629842045, 40.5653627363681], [-74.05002620158643, 40.565318180621134], [-74.05090601705089, 40.5660943421306], [-74.05067916748614, 40.5663108457364], [-74.05107159803778, 40.5667224933978], [-74.05050806403247, 40.566422034160816]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.8133966522335, 40.60436407224537], [-73.81184130264798, 40.60313466508569], [-73.81085365186652, 40.603223713014266], [-73.81053636758675, 40.602495988814695], [-73.80986333857174, 40.60189579000784], [-73.81003425937602, 40.60161090846043], [-73.809912581666, 40.60132020993275], [-73.8100429323135, 40.600954710545174], [-73.80985064502396, 40.60036561675854], [-73.81000132948448, 40.60002868281523], [-73.81014417523032, 40.60005485564217], [-73.80997465251744, 40.59983670280389], [-73...|Polygon|
# |http://nyc.pediacities.com/Resource/Borough/Staten_Island|Staten Island|          5|                                                                                                                             [[[-74.05314036821109, 40.577702715545755], [-74.05406044939875, 40.57711644523887], [-74.05489778210804, 40.57778244091981], [-74.05469316907487, 40.579691632229434], [-74.05485134625391, 40.57970759307761], [-74.05484560052174, 40.579945791427605], [-74.05368629150419, 40.58054875961441], [-74.05293190639817, 40.57990247466585], [-74.05314036821109, 40.577702715545755]]]|Polygon|
# |http://nyc.pediacities.com/Resource/Borough/Staten_Island|Staten Island|          5|[[[-74.08221272914938, 40.64828016229008], [-74.08142228203805, 40.64850472594939], [-74.08072838762374, 40.64827487384626], [-74.07980996428705, 40.648383312987924], [-74.07899546333259, 40.648142554422414], [-74.0765065715286, 40.646968818183346], [-74.074452825637, 40.645067488723235], [-74.07395839976468, 40.645193205445516], [-74.07359107919278, 40.64499892804299], [-74.07349851367621, 40.6450833734751], [-74.07385653684726, 40.645424816099606], [-74.07333813856985, 40.64578311616224], [...|Polygon|
# |http://nyc.pediacities.com/Resource/Borough/Staten_Island|Staten Island|          5|                                         [[[-74.15945602438188, 40.641448333324036], [-74.15997875699617, 40.64144648083637], [-74.16111242522175, 40.641835453737215], [-74.16146036005294, 40.644294969764864], [-74.15798759540647, 40.64386178896607], [-74.1574334920099, 40.643302857779005], [-74.15791589406767, 40.64308269445278], [-74.15813451603348, 40.642632530662986], [-74.15855043770541, 40.642497501306394], [-74.15881093745297, 40.64175863474031], [-74.15945602438188, 40.641448333324036]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.83668274106708, 40.59494669701581], [-73.83670920760008, 40.59471196329251], [-73.83624456552003, 40.59449639775509], [-73.83527199389951, 40.59447351751445], [-73.83511720319443, 40.594365843590154], [-73.8351134853272, 40.59396826505302], [-73.8343321268489, 40.593660767746755], [-73.83422463139404, 40.593348241995784], [-73.83361163952571, 40.59327751230231], [-73.83329545012084, 40.59289022545184], [-73.83308377330326, 40.59298662645058], [-73.83312434323058, 40.592264070070016], [...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.82718282107055, 40.60791977809121], [-73.82679537497147, 40.60772044059308], [-73.8262976301582, 40.60781707222969], [-73.82617361009878, 40.607554111782314], [-73.82639117752834, 40.607357433651224], [-73.82598212776459, 40.60715799759936], [-73.82590092720773, 40.60646593064943], [-73.8264961879578, 40.60622446371774], [-73.82690524584686, 40.60642389797726], [-73.82861671457664, 40.605838484137564], [-73.82866060090227, 40.60625615837476], [-73.82815085191218, 40.607950289832964], [...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                          [[[-73.80509720175088, 40.596755816302355], [-73.80513406252761, 40.59660758897052], [-73.80524832538254, 40.596895032613595], [-73.80519243494219, 40.59719037599558], [-73.80516341154976, 40.5967579920313], [-73.80509720175088, 40.596755816302355]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                          [[[-73.82607472604549, 40.60843779954608], [-73.82661051008792, 40.60819620584166], [-73.82771104235995, 40.608398668130675], [-73.8280507726006, 40.610046296865285], [-73.82688326414812, 40.609596678069416], [-73.82607472604549, 40.60843779954608]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                              [[[-73.83244207358172, 40.60592944953676], [-73.83454144109673, 40.605477383765844], [-73.83587601623046, 40.60563690754552], [-73.83446265620246, 40.60719253294236], [-73.8342834262001, 40.60918568185299], [-73.83373275973203, 40.60928603307335], [-73.83380311515594, 40.60955059185802], [-73.83252192275359, 40.61038499360378], [-73.83032947905774, 40.608487879916545], [-73.83045815392744, 40.60666920140317], [-73.83244207358172, 40.60592944953676]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.79420172624037, 40.60773067561336], [-73.79352152715481, 40.606327591395896], [-73.79399754952594, 40.60608015346259], [-73.79509002319159, 40.60727106010564], [-73.79424799033225, 40.60590038003159], [-73.7969632779504, 40.60411784876774], [-73.80120019667882, 40.60391220065213], [-73.80180285116792, 40.604211431452256], [-73.80428530678606, 40.60451927953054], [-73.80520676583319, 40.60673953810018], [-73.8041969559018, 40.60874419903558], [-73.80159206744116, 40.61023096250123], [-7...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.8049919885511, 40.5967523588775], [-73.80487565214918, 40.59674853593164], [-73.80511185479914, 40.597151047998096], [-73.8047111222805, 40.597674663195114], [-73.80393338922406, 40.597943498583916], [-73.80297943325749, 40.59884430455297], [-73.80167092680179, 40.59889630926943], [-73.80094867862822, 40.59915166461987], [-73.80091500623968, 40.59939076113576], [-73.80077654707625, 40.599162360478296], [-73.8004952637198, 40.599204368068555], [-73.80047379227797, 40.59933155912372], [-...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                                                                                                               [[[-73.79054948559076, 40.59520102103017], [-73.7908062614169, 40.59609339588425], [-73.79059442974037, 40.59610838477277], [-73.79054948559076, 40.59520102103017]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                                                                                                                [[[-73.73944380843434, 40.59702754555849], [-73.73939810824889, 40.59704632565623], [-73.738928507263, 40.59687548946649], [-73.73944380843434, 40.59702754555849]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                           [[[-73.76670827781243, 40.61491086618555], [-73.76825288003396, 40.614877725169364], [-73.7739769201883, 40.61600357567146], [-73.76873454755723, 40.620900868220275], [-73.76745926950545, 40.62051132206254], [-73.76670827781243, 40.61491086618555]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                      [[[-73.739558564649, 40.59698038748012], [-73.73988306007305, 40.59677097418953], [-73.73964853372274, 40.59656715206077], [-73.73974724022861, 40.596542604835086], [-73.73990994690192, 40.59677274452029], [-73.73979634028946, 40.59688267562792], [-73.739558564649, 40.59698038748012]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.81307233892619, 40.62926109964268], [-73.81352502122893, 40.62730617268588], [-73.8125855603813, 40.6283719161837], [-73.81129432207652, 40.62470377900033], [-73.81135581995868, 40.622937515040675], [-73.81185181296345, 40.622097618373914], [-73.81210045334302, 40.621100596814905], [-73.81171450418668, 40.62070357373619], [-73.81171923661803, 40.62009423414049], [-73.8115054253951, 40.61979681095144], [-73.81109451157877, 40.617910252281845], [-73.81024066504999, 40.61648764065423], [-...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.79783533398519, 40.62740871657151], [-73.79783848156967, 40.62701346630362], [-73.79744863612694, 40.627110476260945], [-73.79566256726098, 40.62611400432775], [-73.7992149342777, 40.62408471298848], [-73.79698347650427, 40.62486468974474], [-73.79403741688614, 40.62563519595493], [-73.79362927481347, 40.6251564761949], [-73.79809093107175, 40.62306294824432], [-73.79951085673743, 40.621175533020974], [-73.79992057632705, 40.618575240165946], [-73.80172498640167, 40.619967008731734], [...|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                                                                                                               [[[-73.83032725337065, 40.65513280580329], [-73.83026601851495, 40.65542864678474], [-73.8298891985602, 40.65552282258399], [-73.83032725337065, 40.65513280580329]]]|Polygon|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|                                                                                                                                                                                                                                                                                                        [[[-73.8597553367327, 40.65410417618974], [-73.86098917353914, 40.65520976710516], [-73.86045463170868, 40.655067107366136], [-73.85979242750737, 40.654476157377], [-73.8597553367327, 40.65410417618974]]]|Polygon|
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# only showing top 20 rows

# %%
# Finding the area size of the boroughs
def calculate_area(coordinates):
    polygon = Polygon(list(coordinates[0]))
    return polygon.area

calculate_area_udf = F.udf(calculate_area,DoubleType())

borough_df_sorted = borough_base_df.withColumn("area",calculate_area_udf(F.col("coordinates"))) \
                            .sort(F.col("area").desc()) \
                            .withColumn("row_id",F.monotonically_increasing_id())

geomtree = STRtree([Polygon(coords["coordinates"][0]) for coords in borough_df_sorted.select("coordinates").collect()])
borough_df_sorted
# Out:
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------+------+
# |                                                      @id|      borough|boroughCode|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         coordinates|   type|                 area|row_id|
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------+------+
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.89145055584646, 40.776372179016676], [-73.89145185712489, 40.776512769270866], [-73.8911204433948, 40.777124699736], [-73.8905625059536, 40.77740392096429], [-73.89035193082614, 40.77780032027483], [-73.89008729416801, 40.77778419360687], [-73.88947105399761, 40.77553555096723], [-73.88978900756067, 40.77423686116983], [-73.89019171520673, 40.77364687622498], [-73.88985169959679, 40.77375329736393], [-73.88945486903738, 40.773532951127166], [-73.8858076228666, 40.774022224475374], [-73...|Polygon|  0.02719387322630712|     0|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.95439555417089, 40.739114772522505], [-73.95198794354425, 40.73874762097681], [-73.94652352854787, 40.73692685395815], [-73.94645392267348, 40.73680959046116], [-73.9471998336712, 40.73535517811413], [-73.94706532915389, 40.73440199281923], [-73.94659806707354, 40.734442224347276], [-73.946736923407, 40.735294943719836], [-73.94692902737472, 40.735313140683736], [-73.94662663786626, 40.73586558516741], [-73.94644310074186, 40.7358131844557], [-73.94617195881511, 40.73620288877423], [-7...|Polygon|  0.01870558901900347|     1|
# |http://nyc.pediacities.com/Resource/Borough/Staten_Island|Staten Island|          5|[[[-74.08221272914938, 40.64828016229008], [-74.08142228203805, 40.64850472594939], [-74.08072838762374, 40.64827487384626], [-74.07980996428705, 40.648383312987924], [-74.07899546333259, 40.648142554422414], [-74.0765065715286, 40.646968818183346], [-74.074452825637, 40.645067488723235], [-74.07395839976468, 40.645193205445516], [-74.07359107919278, 40.64499892804299], [-74.07349851367621, 40.6450833734751], [-74.07385653684726, 40.645424816099606], [-74.07333813856985, 40.64578311616224], [...|Polygon|  0.01603547601912208|     2|
# |        http://nyc.pediacities.com/Resource/Borough/Bronx|        Bronx|          2|[[[-73.87294860352858, 40.90444102266826], [-73.85946778700769, 40.90051720926688], [-73.85907692341046, 40.90100799310065], [-73.85941984091325, 40.90139312501249], [-73.85937696525053, 40.90156521816433], [-73.85902704152225, 40.90144490975347], [-73.85886401316355, 40.90171169504956], [-73.85946389958121, 40.90193387763358], [-73.85957882948261, 40.902440842771384], [-73.85926432541882, 40.902669479896545], [-73.8587282483346, 40.9022889705702], [-73.85816000004857, 40.902305710202725], [-...|Polygon| 0.011405869460254603|     3|
# |    http://nyc.pediacities.com/Resource/Borough/Manhattan|    Manhattan|          1|[[[-73.92640556921117, 40.87762147653734], [-73.92629548795446, 40.87748846858917], [-73.92645784900961, 40.877258189008735], [-73.92619292267656, 40.877064419414374], [-73.92555292248268, 40.87710258898463], [-73.92508215701339, 40.87739761061557], [-73.92457036990588, 40.877428912671306], [-73.92329476733927, 40.87726443545978], [-73.92239768169318, 40.876780223141196], [-73.92244468226002, 40.87569183576377], [-73.9226680400197, 40.874981991369474], [-73.92261383040437, 40.87440727210196],...|Polygon| 0.005859077996035753|     4|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.8049919885511, 40.5967523588775], [-73.80487565214918, 40.59674853593164], [-73.80511185479914, 40.597151047998096], [-73.8047111222805, 40.597674663195114], [-73.80393338922406, 40.597943498583916], [-73.80297943325749, 40.59884430455297], [-73.80167092680179, 40.59889630926943], [-73.80094867862822, 40.59915166461987], [-73.80091500623968, 40.59939076113576], [-73.80077654707625, 40.599162360478296], [-73.8004952637198, 40.599204368068555], [-73.80047379227797, 40.59933155912372], [-...|Polygon| 0.002244027128579165|     5|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.82337592129355, 40.638987655897566], [-73.82277105438688, 40.635576914085036], [-73.82209868083655, 40.6340723011468], [-73.82184604252807, 40.63204018843733], [-73.82107505533322, 40.6297337745662], [-73.81991014068154, 40.62784065311699], [-73.8179641483957, 40.62710556569674], [-73.81800752228979, 40.62647634385673], [-73.81769796593271, 40.62596162249622], [-73.81611483429552, 40.62460465517299], [-73.81608643470798, 40.62431541030932], [-73.81672998058578, 40.62387151407256], [-73...|Polygon| 4.664525482037259E-4|     6|
# |    http://nyc.pediacities.com/Resource/Borough/Manhattan|    Manhattan|          1|[[[-73.92133752419281, 40.800852107502166], [-73.92031465521232, 40.79937545928999], [-73.91662985247804, 40.79785813943708], [-73.9154547096642, 40.79706346603097], [-73.91443827233314, 40.79566551786385], [-73.91380428276815, 40.794511846455876], [-73.91378385370597, 40.793836285482065], [-73.91514134426112, 40.792012482994856], [-73.91630577076108, 40.791117369952566], [-73.91617092499695, 40.79101419021154], [-73.91686540584891, 40.790362063464165], [-73.9171062231295, 40.79046861673676],...|Polygon|2.3271655856762013E-4|     7|
# |        http://nyc.pediacities.com/Resource/Borough/Bronx|        Bronx|          2|[[[-73.88885148496335, 40.79870632895875], [-73.8882134885128, 40.798665304638554], [-73.88839250519695, 40.798566297269936], [-73.8882335331365, 40.79824288428591], [-73.88755967580654, 40.79836873243706], [-73.88665108524592, 40.798038196699906], [-73.88375741590161, 40.795708565419794], [-73.88362347511054, 40.795672726309924], [-73.88365516756662, 40.795967230065116], [-73.88320394303747, 40.795544997462244], [-73.8820963368747, 40.795159861043004], [-73.87980493377019, 40.794892251170346...|Polygon|1.7978427201030463E-4|     8|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.84734350666992, 40.62909473971626], [-73.84984630167423, 40.62622449074596], [-73.84727837727986, 40.62662166979185], [-73.84504991718364, 40.62541106188365], [-73.84358010755514, 40.62317816418441], [-73.84614754008332, 40.62222360960777], [-73.84847781581281, 40.62241878479054], [-73.85665510191754, 40.61999364918835], [-73.85947697626031, 40.6186652168382], [-73.86107132214275, 40.61771207937058], [-73.86364988794935, 40.61787877364238], [-73.86404106276495, 40.61920759671407], [-73...|Polygon|1.2096573285815688E-4|     9|
# |        http://nyc.pediacities.com/Resource/Borough/Bronx|        Bronx|          2|[[[-73.79186692005693, 40.85179166130888], [-73.79205731457891, 40.85182557326237], [-73.79017007126302, 40.85228066115337], [-73.79113795170933, 40.852055852573656], [-73.7913345675326, 40.85216606767359], [-73.7912265338512, 40.8522580105032], [-73.791361879799, 40.852225977533905], [-73.7912365597178, 40.85228028988652], [-73.79318284075858, 40.85180857187128], [-73.79311837183839, 40.85157829524081], [-73.79323786787636, 40.85193117467446], [-73.79312894073921, 40.85184807267588], [-73.79...|Polygon|1.1950782695100646E-4|    10|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.84304421296774, 40.617737696390435], [-73.84283573528789, 40.61660943616361], [-73.84400850201857, 40.61704136615358], [-73.84454193473695, 40.61486792167515], [-73.84099942539622, 40.61302912621613], [-73.83825667290544, 40.61384721621641], [-73.84079442408373, 40.60564326638266], [-73.84714809687655, 40.60361424219198], [-73.85179402215203, 40.60689716858372], [-73.85124092910455, 40.607719613414886], [-73.84779013405847, 40.609235385262764], [-73.84816769367684, 40.61253422829742], ...|Polygon| 9.607138763144004E-5|    11|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|                                                                                                                                                                    [[[-73.87084603194216, 40.616967426457514], [-73.87824779324247, 40.61544460833155], [-73.87481386865046, 40.623587189183645], [-73.86684384142534, 40.627829242860294], [-73.86498193495923, 40.625660706040975], [-73.86606533106138, 40.62149332674911], [-73.86626127665741, 40.618456348023955], [-73.87084603194216, 40.616967426457514]]]|Polygon| 9.109297705595764E-5|    12|
# |       http://nyc.pediacities.com/Resource/Borough/Queens|       Queens|          4|[[[-73.79783533398519, 40.62740871657151], [-73.79783848156967, 40.62701346630362], [-73.79744863612694, 40.627110476260945], [-73.79566256726098, 40.62611400432775], [-73.7992149342777, 40.62408471298848], [-73.79698347650427, 40.62486468974474], [-73.79403741688614, 40.62563519595493], [-73.79362927481347, 40.6251564761949], [-73.79809093107175, 40.62306294824432], [-73.79951085673743, 40.621175533020974], [-73.79992057632705, 40.618575240165946], [-73.80172498640167, 40.619967008731734], [...|Polygon| 8.760574248455358E-5|    13|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|                                                                                                                                                                       [[[-73.84721834832132, 40.63196568670605], [-73.84858996643925, 40.630131986806504], [-73.85855836347982, 40.630458288195605], [-73.85613741875908, 40.63508154601464], [-73.84667914840232, 40.638731711757075], [-73.8435200769728, 40.636503685327924], [-73.84504859278645, 40.63317483899963], [-73.84721834832132, 40.63196568670605]]]|Polygon|  7.87410511885683E-5|    14|
# |    http://nyc.pediacities.com/Resource/Borough/Manhattan|    Manhattan|          1|[[[-74.01674756096071, 40.69334336821759], [-74.01540359141649, 40.69306649730911], [-74.01538919768245, 40.693298134665504], [-74.01517482202625, 40.69325668033545], [-74.01525951035649, 40.69303681423187], [-74.01512395634914, 40.69325806929966], [-74.01493136696492, 40.69315577223659], [-74.01515612159493, 40.69301551489163], [-74.01422123084907, 40.692822906344034], [-74.0134356336081, 40.6921154420495], [-74.01250258675189, 40.69230358096553], [-74.01229731492556, 40.69256825483508], [-7...|Polygon|   7.6037752599342E-5|    15|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.8670614947212, 40.58208797679338], [-73.86814728191004, 40.58198890321927], [-73.86896292210413, 40.5816937947886], [-73.87000313642918, 40.58263661481588], [-73.87050597918352, 40.5833419530137], [-73.87061497794424, 40.584915351060324], [-73.87115922675433, 40.58687388796725], [-73.869813564821, 40.58946092678822], [-73.8684967164721, 40.590089850289566], [-73.86759275775206, 40.59100579169063], [-73.86635052164097, 40.59189267656471], [-73.86430826692545, 40.59141474432639], [-73.86...|Polygon|  6.81847134487497E-5|    16|
# |    http://nyc.pediacities.com/Resource/Borough/Manhattan|    Manhattan|          1|[[[-73.94180032729427, 40.769046926624696], [-73.94285528620708, 40.768303494409295], [-73.94943175497112, 40.760548617361174], [-73.95177822025998, 40.75840254987696], [-73.95254079336878, 40.75709531453726], [-73.95519503183569, 40.75477452347619], [-73.95791452493188, 40.752109854525315], [-73.95903975987355, 40.75139248511163], [-73.96117372960866, 40.749498443073904], [-73.96158304938571, 40.74941430110649], [-73.96155080004517, 40.749773889705615], [-73.96111060141877, 40.75060046990072...|Polygon|  6.23157479510608E-5|    17|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.85523067631901, 40.61613145335803], [-73.85530325465115, 40.613145413572845], [-73.8523670438485, 40.61315598907671], [-73.85376845962078, 40.61408759651684], [-73.85263195046848, 40.61509408190895], [-73.84973986306488, 40.61515605814335], [-73.85010857555373, 40.61021219334599], [-73.85515592288351, 40.60612051300153], [-73.85708638173242, 40.60646824293357], [-73.8570405272773, 40.60829948887601], [-73.85901755318284, 40.609475753925075], [-73.85924855452198, 40.611254830874294], [-...|Polygon|5.9427897594547475E-5|    18|
# |     http://nyc.pediacities.com/Resource/Borough/Brooklyn|     Brooklyn|          3|[[[-73.85243335807019, 40.59733339779523], [-73.85399559599406, 40.59668348634671], [-73.85465863090118, 40.596578388927554], [-73.85492648581453, 40.5963016643732], [-73.85673364394977, 40.596075764354], [-73.86044420534071, 40.596471905596324], [-73.86054977985194, 40.59706302019161], [-73.8627482079264, 40.599071205924574], [-73.8632866313415, 40.599810042163206], [-73.86335999147613, 40.600322202771125], [-73.86297506260973, 40.60101827261558], [-73.8618718984724, 40.602164325815885], [-7...|Polygon|  5.56340780263587E-5|    19|
# +---------------------------------------------------------+-------------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+---------------------+------+
# only showing top 20 rows

# %%
def findBorough(x,y):
    point = Point(x,y)
    nearestLocIndex = geomtree.nearest(point)
    return nearestLocIndex

# %%
from pyspark.sql.types import IntegerType, StringType

# Define a function to find the point borough
def update_borough(longitude, latitude):
    borough = findBorough(longitude, latitude)
    return int(borough) if borough is not None else -1

# Create a user-defined function (UDF)
update_borough_udf = F.udf(update_borough, IntegerType())

# Apply the UDF to update the start and end borough column (finding the borough index)
taxiDataDf_with_boroughs = taxiDataDf.withColumn("startBoroughIndex", update_borough_udf(taxiDataDf["pickup_longitude"], taxiDataDf["pickup_latitude"]))
taxiDataDf_with_boroughs = taxiDataDf_with_boroughs.withColumn("endBoroughIndex", update_borough_udf(taxiDataDf["dropoff_longitude"], taxiDataDf["dropoff_latitude"]))

# %%
taxiDataDf_with_boroughs.groupBy("startBoroughIndex").count().orderBy("startBoroughIndex")
# Out:
# +-----------------+-----+
# |startBoroughIndex|count|
# +-----------------+-----+
# |                0| 5957|
# |                1| 1970|
# |                2|   22|
# |                3|   89|
# |                4|90156|
# |                5| 1751|
# |                7|    5|
# |               17|   19|
# |               22|    2|
# |               26|    1|
# |               31|   10|
# |               33|    5|
# |               35|    3|
# |               50|    1|
# |               58|    2|
# |               65|    1|
# |               68|    1|
# |               88|    3|
# |               92|    1|
# +-----------------+-----+

# %%
#new_taxidf = taxiDataDf_with_boroughs.withColumn("startBorough",borough_df_sorted.join(taxiDataDf_with_boroughs,borough_df_sorted.row_id == taxiDataDf_with_boroughs.startBoroughIndex,"inner").borough)
#new_taxidf
#taxiDataDf_with_boroughs.join(borough_df_sorted,borough_df_sorted.row_id == taxiDataDf_with_boroughs.startBoroughIndex,"left").columns
#borough_join_table = borough_df_sorted.select(F.col("borough").alias("joinBorough"),F.col("boroughCode").alias("joinBoroughCode"),F.col("row_id").alias("joinRowId"))
#borough_join_table

#taxiDataDf_with_boroughs.withColumn("startBorough",borough_join_table.alias("borough_join_table").join(taxiDataDf_with_boroughs.alias("taxiDataDf_with_boroughs"),col("borough_join_table.joinRowId") == col("taxiDataDf_with_boroughs.startBoroughIndex"),"left")["myTmpBorough"])
#borough_join_table.alias("borough_join_table").join(taxiDataDf_with_boroughs.alias("taxiDataDf_with_boroughs"),col("borough_join_table.joinRowId") == col("taxiDataDf_with_boroughs.startBoroughIndex"),"left").withColumnRenamed("joinBorough","myTmpBorough")["myTmpBorough"]
#startBoroughColumn = borough_df_sorted.join(taxiDataDf_with_boroughs,borough_df_sorted.row_id == taxiDataDf_with_boroughs.startBoroughIndex,"left").borough
#taxiDataDf_with_boroughs.withColumn("startBorough", startBoroughColumn)

# %% [markdown]
# ## Query 1: Utilization

# %% [markdown]
# Utilization: This is per taxi/driver. This can be computed by computing the idle
# time per taxi. We will elaborate on that more later

# %%
taxiUtilizationBaseDf = taxiDataDf_with_boroughs.filter("trip_time_in_secs > 0 or trip_time_in_secs <= 3600 * 4")
              

utilizationWindow = Window.partitionBy("hack_license").orderBy("pickup_datetime")

idleTimeDf = taxiUtilizationBaseDf.withColumn("idle_time",(F.col("pickup_datetime") - F.lag(F.col("dropoff_datetime")).over(utilizationWindow)).cast("long"))
idleTimeDf
# Out:
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+-----------------+---------------+---------+
# |                       medallion|                    hack_license|vendor_id|rate_code|store_and_fwd_flag|    pickup_datetime|   dropoff_datetime|passenger_count|trip_time_in_secs|trip_distance|pickup_longitude|pickup_latitude|dropoff_longitude|dropoff_latitude|startBoroughIndex|endBoroughIndex|idle_time|
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+-----------------+---------------+---------+
# |0E05D2A5CCFCA4AA81B3E6772632CA08|008BE4F3FF93935048998BB183D27263|      VTS|        1|              NULL|2013-01-13 02:36:00|2013-01-13 02:42:00|              5|              360|          1.1|      -73.983185|      40.738731|         -73.9944|       40.746029|                4|              4|     NULL|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 10:07:00|2013-01-13 10:25:00|              5|             1080|         1.87|      -73.930962|      40.738007|       -73.930962|       40.738007|                0|              0|     NULL|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 10:42:00|2013-01-13 11:01:00|              5|             1140|          3.9|      -73.930962|      40.738007|       -73.930962|       40.738007|                0|              0|     1020|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 11:29:00|2013-01-13 11:42:00|              5|              780|         4.25|      -73.930962|      40.738007|       -73.930962|       40.738007|                0|              0|     1680|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 11:43:00|2013-01-13 11:58:00|              5|              900|         4.83|      -73.930962|      40.738007|       -73.930962|       40.738007|                0|              0|       60|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 12:00:00|2013-01-13 12:08:00|              5|              480|          1.3|      -73.930962|      40.738007|       -73.995804|         40.7169|                0|              4|      120|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 12:14:00|2013-01-13 12:22:00|              5|              480|         1.14|       -73.99839|      40.713715|       -73.996864|        40.72543|                4|              4|      360|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 12:24:00|2013-01-13 12:35:00|              5|              660|         3.32|      -73.996864|       40.72543|       -74.004189|       40.725327|                4|              4|      120|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 12:42:00|2013-01-13 12:50:00|              5|              480|         1.96|      -73.979401|      40.776546|       -73.977989|       40.760052|                4|              4|      420|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 14:00:00|2013-01-13 14:02:00|              5|              120|         0.61|      -73.994926|      40.761173|       -73.994926|       40.761173|                4|              4|     4200|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 14:37:00|2013-01-13 14:42:00|              5|              300|         0.52|      -73.994926|      40.761173|       -73.994926|       40.761173|                4|              4|     2100|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 14:58:00|2013-01-13 15:04:00|              5|              360|         0.99|      -73.994926|      40.761173|       -73.994926|       40.761173|                4|              4|      960|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 15:11:00|2013-01-13 15:35:00|              5|             1440|          2.0|      -74.004555|      40.742172|       -74.004959|       40.715908|                4|              4|      420|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 15:39:00|2013-01-13 15:49:00|              5|              600|         1.28|      -74.008736|      40.711288|       -74.016167|       40.715595|                4|              4|      240|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 15:51:00|2013-01-13 15:57:00|              5|              360|         0.81|      -74.010994|      40.717907|       -74.008644|        40.71133|                4|              4|      120|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 16:05:00|2013-01-13 16:18:00|              5|              780|         4.63|      -74.003845|      40.707199|       -74.001732|       40.709354|                4|              4|      480|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 16:20:00|2013-01-13 16:48:00|              5|             1680|         2.64|      -74.001732|      40.709354|       -74.001732|       40.709354|                4|              4|      120|
# |CA853C09FCD9FE8D830096584392D1AA|00927C48BA4C1B2B1B6403B8BFE1AB03|      VTS|        1|              NULL|2013-01-13 17:22:00|2013-01-13 17:30:00|              5|              480|         1.59|      -74.002235|      40.708977|       -74.002235|       40.708977|                4|              4|     2040|
# |8CD6D2B1CD25C9CE1D30F74F7F26285A|00AE05F56D451E89E6F83EBE384FF5E6|      VTS|        1|              NULL|2013-01-13 06:49:00|2013-01-13 06:52:00|              1|              180|          0.6|      -73.982658|      40.723301|       -73.974815|       40.721645|                4|              4|     NULL|
# |8CD6D2B1CD25C9CE1D30F74F7F26285A|00AE05F56D451E89E6F83EBE384FF5E6|      VTS|        1|              NULL|2013-01-13 07:22:00|2013-01-13 07:29:00|              1|              420|         1.38|      -73.982269|      40.728596|       -74.001495|       40.737251|                4|              4|     1800|
# +--------------------------------+--------------------------------+---------+---------+------------------+-------------------+-------------------+---------------+-----------------+-------------+----------------+---------------+-----------------+----------------+-----------------+---------------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Query 2: Average next trip time

# %% [markdown]
# The average time it takes for a taxi to find its next fare(trip) per destination borough. This can be computed by finding the time difference, e.g. in seconds, between the trip's drop off and the next trip's pick up.

# %%
# ?

# %% [markdown]
# ## Query 3: Trips started in one borough

# %% [markdown]
# The number of trips that started and ended within the same borough,

# %%
#cleaned_taxi_df = taxiDataDf_with_boroughs.na.drop()

# %%
#display(cleaned_taxi_df)

# %%
#same_borough_df = taxiDataDf_with_boroughs.filter(F.col("startBorough") == F.col("endBorough"))
#display(same_borough_df)

# %%
#taxi_length = cleaned_taxi_df.agg(count(when(col("startBorough") == col("endBorough"), True)))
#print(taxi_length)

# %% [markdown]
# ## Query 4: Trips between different boroughs

# %% [markdown]
# The number of trips that started in one borough and ended in another one

# %%
# ?
